# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data/virat_rohit_linechart.csv')

# %%
df.dropna(how="all", inplace=True, axis=1)

# %%
df
# Out:
#     Year  Virat_Runs  Rohit_Runs
# 0   2008         165         404
# 1   2009         246         362
# 2   2010         307         404
# 3   2011         557         372
# 4   2012         364         433
# 5   2013         634         538
# 6   2014         359         390
# 7   2015         505         482
# 8   2016         973         489
# 9   2017         308         333
# 10  2018         530         286
# 11  2019         464         405
# 12  2020         466         332
# 13  2021         405         250
# 14  2022         341         268
# 15  2023         639         332
# 16  2024         741         418

# %%
plt.plot(df['Year'], df['Virat_Runs'], label='Virat Kohli', color="Blue")
plt.plot(df['Year'], df['Rohit_Runs'], label='Rohit Sharma', color="Red", linestyle='dashed')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
figure , axis = plt.subplots(2,2, figsize=(6,6), sharex=True, sharey=True)
axis[0,0].plot(df['Year'], df['Virat_Runs'], label='Virat Kohli', color="Blue" )
axis[0,0].set_title('Virat Kohli Runs')
axis[0,1].plot(df['Year'], df['Rohit_Runs'], label='Rohit Sharma', color="Red")
axis[0,1].set_title('Rohit Sharma Runs')
axis[1,0].scatter(df['Year'], df['Virat_Runs'], label='Virat Kohli', color="Blue")
axis[1,0].set_title('Virat Kohli Runs Scatter')
axis[1,1].scatter(df['Year'], df['Rohit_Runs'], label='Rohit Sharma', color="Red")
axis[1,1].set_title('Rohit Sharma Runs Scatter')
figure.suptitle('Virat Kohli and Rohit Sharma Runs Over the Years')
plt.tight_layout()

# %%
plt.subplot(2,2,1)
plt.plot(df['Year'], df['Virat_Runs'], label='Virat Kohli', color="Blue" )
plt.title('Virat Kohli Runs')
plt.subplot(2,2,2)
plt.plot(df['Year'], df['Rohit_Runs'], label='Rohit Sharma', color="Red")
plt.title('Rohit Sharma Runs')
# Out:
# Text(0.5, 1.0, 'Rohit Sharma Runs')

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(df['total_bill'], df['tip'])
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Scatter Plot of Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Total Bill vs Tip')

# %%
sns.scatterplot(x = df['total_bill'], y = df['tip'] , hue = df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(df['total_bill'], df['tip'], c=df['sex'].map({'Male': 'blue', 'Female': 'red'}))

# %%
males = df[df['sex'] == 'Male']
females = df[df['sex'] == 'Female']
plt.scatter(males['total_bill'], males['tip'], color='blue', label='Male')
plt.scatter(females['total_bill'], females['tip'], color='red', label='Female')
plt.legend()

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=df, x='total_bill', y='tip', hue='sex',size='size', kind='scatter', col="smoker" , row="sex")
# fecesiting 
# rel can create two types of plots scatter and line plot

# %%
sns.barplot(data=df, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.bar(df['day'], df['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %%
sum_total_bill = df.groupby('day')['total_bill'].sum().reset_index()
sum_total_bill
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
plt.bar(sum_total_bill['day'], sum_total_bill['total_bill'])
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot(data=sum_total_bill, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.relplot(x=df["total_bill"], y=df["tip"], hue=df["sex"], col = df["day"],col_wrap=2)

# %%
grid =sns.FacetGrid(data=df, col='sex').map(sns.scatterplot, 'total_bill', 'tip').add_legend()

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue='species')

# %%
# Distribution Plots
# histogram, kde, rug, ecdf

# %%
plt.hist(df['total_bill'],bins=[0,5,10,15,20,25,30,35,40,45,50])
# Out:
# (array([ 1., 16., 63., 67., 41., 24., 16.,  6.,  5.,  4.]),
#  array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(data=df, x='total_bill',  kind="ecdf")

# %%
sns.displot(data=df , x='total_bill', kind="kde")
sns.rugplot(data=df, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=df , x='total_bill',y='tip', kind="kde")

# %%
sns.displot(data=df , x='total_bill',y='tip', kind="hist")

# %%
sns.displot(data=df , x='total_bill',y='tip', kind="hist" , hue='sex',col="time")

# %%
sns.displot(data=df, x='total_bill', kind="hist", hue='sex', col="time")
sns.displot(data=df, x='total_bill', kind="kde", hue='sex', col="time")

# %%
# create subplots for hist and kde for total_bill with hue as sex and col as time
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(
    data=df[df['time'] == 'Lunch'],
    x='total_bill',
    hue='sex',
    ax=axes[0]
)

sns.histplot(
    data=df[df['time'] == 'Dinner'],
    x='total_bill',
    hue='sex',
    ax=axes[1]
)



plt.show()

# %%
tip2 = df.groupby('day')[['total_bill','tip']].sum().reset_index()
tip2.plot(kind='bar', x='day', y=['total_bill', 'tip'])
# Out:
# <Axes: xlabel='day'>

# %%
X = np.arange(len(tip2['day']))
plt.bar(x=X, height=tip2['tip'], width=0.25, label='Tip')
plt.bar(x=X + 0.25, height=tip2['total_bill'], width=0.25, label='Total Bill')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=X, height=tip2['tip'], width=0.25, label='Tip', bottom=tip2['total_bill'])
plt.bar(x=X, height=tip2['total_bill'], width=0.25, label='Total Bill')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=tip2['day'], width=tip2['total_bill'], height=0.5, label='Total Bill')
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot(data=df, x='day', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=df, x='day', y='total_bill', hue='sex',estimator=sum)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
melted_tip = pd.melt(df, id_vars=['day'], value_vars=['tip', 'total_bill'], var_name='Bill_Type', value_name='Amount')
melted_tip
# Out:
#       day   Bill_Type  Amount
# 0     Sun         tip    1.01
# 1     Sun         tip    1.66
# 2     Sun         tip    3.50
# 3     Sun         tip    3.31
# 4     Sun         tip    3.61
# ..    ...         ...     ...
# 483   Sat  total_bill   29.03
# 484   Sat  total_bill   27.18
# 485   Sat  total_bill   22.67
# 486   Sat  total_bill   17.82
# 487  Thur  total_bill   18.78
#
# [488 rows x 3 columns]

# %%
sns.barplot(data=melted_tip, x='day', y='Amount', hue='Bill_Type')
# Out:
# <Axes: xlabel='day', ylabel='Amount'>

# %%
sns.barplot(data=melted_tip, x='day', y='Amount', hue='Bill_Type')
# Out:
# <Axes: xlabel='day', ylabel='Amount'>

# %%
sns.barplot(data=melted_tip, x='day', y='Amount', hue='Bill_Type', estimator=sum)
# Out:
# <Axes: xlabel='day', ylabel='Amount'>

# %%
sns.catplot(data=melted_tip, x='day', y='Amount', hue='Bill_Type',kind='bar')

# %%
sns.catplot(data=melted_tip, x='day', y='Amount', hue='Bill_Type',kind='bar',col='Bill_Type')

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.bar(x=X, height=tip2['tip'], width=0.25, label='Tip')
plt.subplot(1, 2, 2)
plt.bar(x=X, height=tip2['total_bill'], width=0.25, label='Total Bill',color='orange')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.pie(tip2['total_bill'], labels=tip2['day'])
plt.show()

# %%
plt.pie(tip2['total_bill'], labels=tip2['day'], autopct='%.2f%%', wedgeprops={'width': 0.4})
textprops = {'fontsize': 12, 'color': 'black'}
plt.show()

# %%
plt.pie(tip2["total_bill"],labels= tip2["day"],autopct = "%.2f%%",explode = [0.2,0,0,0])
plt.show()

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris .corr(numeric_only =True)    # correlation matrix for numeric columns in the iris dataset. correlation matrix only possible for numeric columns. The correlation matrix shows the pairwise correlation coefficients between the numeric columns in the dataset.
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris ['species'].unique
# Out:
# <bound method Series.unique of 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: str>

# %%
sns.heatmap(iris.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import plotly.express as px
gap = px.data.gapminder()

# %%
gap.sample(20)
# Out:
#                      country continent  year  lifeExp        pop  \
# 699                    India      Asia  1967   47.193  506000000
# 1138                 Nigeria    Africa  2002   46.608  119901274
# 756                   Israel      Asia  1952   65.390    1620914
# 1461               Swaziland    Africa  1997   54.289    1054486
# 1088             Netherlands    Europe  1992   77.420   15174244
# 969               Mauritania    Africa  1997   60.430    2444741
# 1496                   Syria      Asia  1992   69.249   13219062
# 144   Bosnia and Herzegovina    Europe  1952   53.820    2791000
# 192             Burkina Faso    Africa  1952   31.975    4469979
# 659                 Honduras  Americas  2007   70.198    7483763
# 494                  Eritrea    Africa  1962   40.158    1666618
# 365            Cote d'Ivoire    Africa  1977   52.374    7459574
# 140                  Bolivia  Americas  1992   59.957    6893451
# ...

# %%
gap.query("country in ['India', 'Pakistan','Singapore', 'China']")
# Out:
#         country continent  year   lifeExp         pop     gdpPercap iso_alpha  \
# 288       China      Asia  1952  44.00000   556263527    400.448611       CHN
# 289       China      Asia  1957  50.54896   637408000    575.987001       CHN
# 290       China      Asia  1962  44.50136   665770000    487.674018       CHN
# 291       China      Asia  1967  58.38112   754550000    612.705693       CHN
# 292       China      Asia  1972  63.11888   862030000    676.900092       CHN
# 293       China      Asia  1977  63.96736   943455000    741.237470       CHN
# 294       China      Asia  1982  65.52500  1000281000    962.421381       CHN
# 295       China      Asia  1987  67.27400  1084035000   1378.904018       CHN
# 296       China      Asia  1992  68.69000  1164970000   1655.784158       CHN
# 297       China      Asia  1997  70.42600  1230075000   2289.234136       CHN
# 298       China      Asia  2002  72.02800  1280400000   3119.280896       CHN
# ...

# %%
numeric_data = gap[['year', 'lifeExp', 'pop', 'gdpPercap']]
plt.figure(figsize=(8, 6))
sns.heatmap(
    numeric_data.corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)
plt.title('Correlation Heatmap of Gapminder Dataset')
plt.show()

# %%
stocks = px.data.stocks()
stocks.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
px.line(data_frame=stocks,x="date",y=["GOOG"],title="Google Stock Price",markers=True)

# %%
px.line(data_frame=stocks,x="date",y=["GOOG","AAPL"],title="Google Stock Price",markers=True)

# %%
import seaborn as sns 
tip = sns.load_dataset('tips')
tip2 = tip.groupby('day')[['total_bill','tip']].sum().reset_index()
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
px.line(data_frame = tip2 ,  x=tip2['day'],y=["total_bill","tip"],title="Total Bill and Tip by Day",markers=True,symbol_sequence = ["star"])

# %%
t = px.line(data_frame=tip2,x=tip2['day'],y=["total_bill",'tip'],title='Total Bill and Tip by Day',markers=True,symbol_sequence=["star"])
t.update_traces(mode="markers+lines")

# %%
t = px.line(data_frame=tip2,x=tip2)
